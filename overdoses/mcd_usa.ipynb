# %%
# Load dependencies
import pandas as pd

# %%
# Identify files to load
mcd1_csv = "Resources/mcd1.csv"
mcd2_csv = "Resources/mcd2.csv"

# %%
# Read files into Pandas data frames
mcd1_df = pd.read_csv(mcd1_csv)
mcd2_df = pd.read_csv(mcd2_csv)

# %%
# Check that first data frame looks good
mcd1_df.head()

# %%
# Check that second data frame looks good
mcd2_df.head()

# %%
# Count rows of data in the first data frame (should be 3684)
mcd1_df.count()

# %%
# Count rows of data in the second data frame (should be 3437)
mcd2_df.count()

# %%
# Combine both data frames into one new data frame
# Append second data frame to end of first data fram and re-index
mcdTot_df = mcd1_df.append(mcd2_df, ignore_index=True)
# Check that new data frame looks good
mcdTot_df.head()

# %%
# Check that all rows are in new data frame (should be 7121)
mcdTot_df.count()

# %%
mcdTot_df.to_csv(r'Resources\multiplecauseofdeath.csv')

# %%
# Checking out the created CSV
mcd_df = pd.read_csv('multiplecauseofdeath.csv')
display(mcd_df.head())
display(mcd_df.info())
# Out:
#    Unnamed: 0    State  State Code              County  County Code  Year  \
# 0           0  Alabama           1  Baldwin County, AL         1003  2014
# 1           1  Alabama           1  Baldwin County, AL         1003  2015
# 2           2  Alabama           1  Baldwin County, AL         1003  2015
# 3           3  Alabama           1  Calhoun County, AL         1015  2014
# 4           4  Alabama           1  Calhoun County, AL         1015  2015
#
#                     UCD - Drug/Alcohol Induced Cause  \
# 0  Drug poisonings (overdose) Unintentional (X40-...
# 1  Drug poisonings (overdose) Unintentional (X40-...
# 2  Drug poisonings (overdose) Unintentional (X40-...
# 3  Drug poisonings (overdose) Unintentional (X40-...
# 4  Drug poisonings (overdose) Unintentional (X40-...
#
#   UCD - Drug/Alcohol Induced Cause Code  \
# 0                                    D1
# 1                                    D1
# 2                                    D1
# 3                                    D1
# 4                                    D1
#
#                              Multiple Cause of death  \
# 0  Other and unspecified drugs, medicaments and b...
# 1                                      Other opioids
# 2  Other and unspecified drugs, medicaments and b...
# 3  Other and unspecified drugs, medicaments and b...
# 4  Other and unspecified drugs, medicaments and b...
#
#   Multiple Cause of death Code  ...  Population  Crude Rate  \
# 0                        T50.9  ...      200111  Unreliable
# 1                        T40.2  ...      203709  Unreliable
# 2                        T50.9  ...      203709         9.8
# 3                        T50.9  ...      115916  Unreliable
# 4                        T50.9  ...      115620  Unreliable
#
#   Crude Rate Lower 95% Confidence Interval  \
# 0                                      3.8
# 1                                      2.7
# 2                                      6.0
# 3                                      8.5
# 4                                      9.9
#
#    Crude Rate Upper 95% Confidence Interval  Crude Rate Standard Error  \
# 0                                      11.7                        1.9
# 1                                       9.7                        1.6
# 2                                      15.2                        2.2
# 3                                      23.5                        3.6
# 4                                      25.7                        3.8
#
#    Age Adjusted Rate Age Adjusted Rate Lower 95% Confidence Interval  \
# 0         Unreliable                                             3.8
# 1         Unreliable                                             2.6
# 2               10.1                                             6.1
# 3         Unreliable                                             8.6
# 4         Unreliable                                            10.8
#
#    Age Adjusted Rate Upper 95% Confidence Interval  \
# 0                                             12.1
# 1                                              9.8
# 2                                             15.8
# 3                                             23.5
# 4                                             28.1
#
#    Age Adjusted Rate Standard Error  % of Total Deaths
# 0                               1.9              0.00%
# 1                               1.7              0.00%
# 2                               2.3              0.00%
# 3                               3.6              0.00%
# 4                               4.2              0.00%
#
# [5 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7121 entries, 0 to 7120
# Data columns (total 21 columns):
# Unnamed: 0                                         7121 non-null int64
# State                                              7121 non-null object
# State Code                                         7121 non-null int64
# County                                             7121 non-null object
# County Code                                        7121 non-null int64
# Year                                               7121 non-null int64
# UCD - Drug/Alcohol Induced Cause                   7121 non-null object
# UCD - Drug/Alcohol Induced Cause Code              7121 non-null object
# Multiple Cause of death                            7121 non-null object
# Multiple Cause of death Code                       7121 non-null object
# Deaths                                             7121 non-null int64
# Population                                         7121 non-null int64
# Crude Rate                                         7121 non-null object
# Crude Rate Lower 95% Confidence Interval           7121 non-null float64
# Crude Rate Upper 95% Confidence Interval           7121 non-null float64
# Crude Rate Standard Error                          7121 non-null float64
# Age Adjusted Rate                                  7121 non-null object
# Age Adjusted Rate Lower 95% Confidence Interval    7121 non-null float64
# Age Adjusted Rate Upper 95% Confidence Interval    7121 non-null float64
# Age Adjusted Rate Standard Error                   7121 non-null float64
# % of Total Deaths                                  7121 non-null object
# dtypes: float64(6), int64(6), object(9)
# memory usage: 1.1+ MB
# None

# %%
# Drop index column
mcd_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Export the df as csv
mcd_df.to_csv('overdoses.csv',index=False)
